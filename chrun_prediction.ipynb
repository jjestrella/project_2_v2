# %%
# Import Modules
import pandas as pd
from pathlib import Path
from sklearn import tree
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# Needed for decision tree visualization
import pydotplus
from IPython.display import Image

# %% [markdown]
# ## Loading Telco Churn CSV raw data

# %%
#Loading data obtained from Kaggle
customer_churn_df = pd.read_csv(Path("Resources/WA_Fn-UseC_-Telco-Customer-Churn.csv"))

#printing the first 5 rows
customer_churn_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  0002-ORFBO  Female              0     Yes        Yes       9          Yes
# 1  0003-MKNFE    Male              0      No         No       9          Yes
# 2  0004-TLHLJ    Male              0      No         No       4          Yes
# 3  0011-IGKFF    Male              1     Yes         No      13          Yes
# 4  0013-EXCHZ  Female              1     Yes         No       3          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL             No  ...               No
# 1           Yes             DSL             No  ...               No
# 2            No     Fiber optic             No  ...              Yes
# 3            No     Fiber optic             No  ...              Yes
# 4            No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0         Yes         Yes              No        One year              Yes
# 1          No          No             Yes  Month-to-month               No
# 2          No          No              No  Month-to-month              Yes
# 3          No         Yes             Yes  Month-to-month              Yes
# 4         Yes         Yes              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0      Mailed check           65.6        593.30     No
# 1      Mailed check           59.9        542.40     No
# 2  Electronic check           73.9        280.85    Yes
# 3  Electronic check           98.0       1237.85    Yes
# 4      Mailed check           83.9        267.40    Yes
#
# [5 rows x 21 columns]

# %%
# Split target column from dataset
y = customer_churn_df['Churn']
X = customer_churn_df.drop(columns='Churn')

# Set Index
X = X.set_index('customerID')

# %%
# Print first 5 entries for target
y[:5]
# Out:
# 0     No
# 1     No
# 2    Yes
# 3    Yes
# 4    Yes
# Name: Churn, dtype: object

# %%
customer_churn_df = customer_churn_df.replace({'Partner': {'Yes': 1, 'No': 0}})
customer_churn_df = customer_churn_df.replace({'Dependents': {'Yes': 1, 'No': 0}})
customer_churn_df = customer_churn_df.replace({'PhoneService': {'Yes': 1, 'No': 0}})
customer_churn_df = customer_churn_df.replace({'MultipleLines': {'Yes': 1, 'No': 0, "No phone service" : 0}})
customer_churn_df = customer_churn_df.replace({'OnlineSecurity': {'Yes': 1, 'No': 0, "No internet service" : 0}})
customer_churn_df = customer_churn_df.replace({'OnlineBackup': {'Yes': 1, 'No': 0, "No internet service" : 0}})
customer_churn_df = customer_churn_df.replace({'DeviceProtection': {'Yes': 1, 'No': 0, "No internet service" : 0}})
customer_churn_df = customer_churn_df.replace({'TechSupport': {'Yes': 1, 'No': 0, "No internet service" : 0}})
customer_churn_df = customer_churn_df.replace({'StreamingTV': {'Yes': 1, 'No': 0, "No internet service" : 0}})
customer_churn_df = customer_churn_df.replace({'StreamingMovies': {'Yes': 1, 'No': 0, "No internet service" : 0}})
customer_churn_df = customer_churn_df.replace({'PaperlessBilling': {'Yes': 1, 'No': 0, "No internet service" : 0}})
customer_churn_df = customer_churn_df.replace({'Churn': {'Yes': 1, 'No': 0, "No internet service" : 0}})


customer_churn_df
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     0002-ORFBO  Female              0        1           1       9
# 1     0003-MKNFE    Male              0        0           0       9
# 2     0004-TLHLJ    Male              0        0           0       4
# 3     0011-IGKFF    Male              1        1           0      13
# 4     0013-EXCHZ  Female              1        1           0       3
# ...          ...     ...            ...      ...         ...     ...
# 7038  9987-LUTYD  Female              0        0           0      13
# 7039  9992-RRAMN    Male              0        1           0      22
# 7040  9992-UJOEL    Male              0        0           0       2
# 7041  9993-LHIEB    Male              0        1           1      67
# 7042  9995-HOTOH    Male              0        1           1      63
#
#       PhoneService  MultipleLines InternetService  OnlineSecurity  ...  \
# 0                1              0             DSL               0  ...
# 1                1              1             DSL               0  ...
# 2                1              0     Fiber optic               0  ...
# 3                1              0     Fiber optic               0  ...
# 4                1              0     Fiber optic               0  ...
# ...            ...            ...             ...             ...  ...
# 7038             1              0             DSL               1  ...
# 7039             1              1     Fiber optic               0  ...
# 7040             1              0             DSL               0  ...
# 7041             1              0             DSL               1  ...
# 7042             0              0             DSL               1  ...
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 0                    0            1            1                0
# 1                    0            0            0                1
# 2                    1            0            0                0
# 3                    1            0            1                1
# 4                    0            1            1                0
# ...                ...          ...          ...              ...
# 7038                 0            1            0                0
# 7039                 0            0            0                1
# 7040                 0            0            0                0
# 7041                 1            1            0                1
# 7042                 1            0            1                1
#
#             Contract PaperlessBilling     PaymentMethod MonthlyCharges  \
# 0           One year                1      Mailed check          65.60
# 1     Month-to-month                0      Mailed check          59.90
# 2     Month-to-month                1  Electronic check          73.90
# 3     Month-to-month                1  Electronic check          98.00
# 4     Month-to-month                1      Mailed check          83.90
# ...              ...              ...               ...            ...
# 7038        One year                0      Mailed check          55.15
# 7039  Month-to-month                1  Electronic check          85.10
# 7040  Month-to-month                1      Mailed check          50.30
# 7041        Two year                0      Mailed check          67.85
# 7042        Two year                0  Electronic check          59.00
#
#       TotalCharges  Churn
# 0           593.30      0
# 1           542.40      0
# 2           280.85      1
# 3          1237.85      1
# 4           267.40      1
# ...            ...    ...
# 7038        742.90      0
# 7039       1873.70      1
# 7040         92.75      0
# 7041       4627.65      0
# 7042       3707.60      0
#
# [7043 rows x 21 columns]

# %%
customer_churn_df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner               int64
# Dependents            int64
# tenure                int64
# PhoneService          int64
# MultipleLines         int64
# InternetService      object
# OnlineSecurity        int64
# OnlineBackup          int64
# DeviceProtection      int64
# TechSupport           int64
# StreamingTV           int64
# StreamingMovies       int64
# Contract             object
# PaperlessBilling      int64
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                 int64
# dtype: object

# %%
# Encode the categorical variables using get_dummies
X = pd.get_dummies(X)

X.head()
# Out:
#             SeniorCitizen  tenure  MonthlyCharges  TotalCharges  \
# customerID
# 0002-ORFBO              0       9            65.6        593.30
# 0003-MKNFE              0       9            59.9        542.40
# 0004-TLHLJ              0       4            73.9        280.85
# 0011-IGKFF              1      13            98.0       1237.85
# 0013-EXCHZ              1       3            83.9        267.40
#
#             gender_Female  gender_Male  Partner_No  Partner_Yes  \
# customerID
# 0002-ORFBO              1            0           0            1
# 0003-MKNFE              0            1           1            0
# 0004-TLHLJ              0            1           1            0
# 0011-IGKFF              0            1           0            1
# 0013-EXCHZ              1            0           0            1
#
#             Dependents_No  Dependents_Yes  ...  StreamingMovies_Yes  \
# customerID                                 ...
# 0002-ORFBO              0               1  ...                    0
# 0003-MKNFE              1               0  ...                    1
# 0004-TLHLJ              1               0  ...                    0
# 0011-IGKFF              1               0  ...                    1
# 0013-EXCHZ              1               0  ...                    0
#
#             Contract_Month-to-month  Contract_One year  Contract_Two year  \
# customerID
# 0002-ORFBO                        0                  1                  0
# 0003-MKNFE                        1                  0                  0
# 0004-TLHLJ                        1                  0                  0
# 0011-IGKFF                        1                  0                  0
# 0013-EXCHZ                        1                  0                  0
#
#             PaperlessBilling_No  PaperlessBilling_Yes  \
# customerID
# 0002-ORFBO                    0                     1
# 0003-MKNFE                    1                     0
# 0004-TLHLJ                    0                     1
# 0011-IGKFF                    0                     1
# 0013-EXCHZ                    0                     1
#
#             PaymentMethod_Bank transfer (automatic)  \
# customerID
# 0002-ORFBO                                        0
# 0003-MKNFE                                        0
# 0004-TLHLJ                                        0
# 0011-IGKFF                                        0
# 0013-EXCHZ                                        0
#
#             PaymentMethod_Credit card (automatic)  \
# customerID
# 0002-ORFBO                                      0
# 0003-MKNFE                                      0
# 0004-TLHLJ                                      0
# 0011-IGKFF                                      0
# 0013-EXCHZ                                      0
#
#             PaymentMethod_Electronic check  PaymentMethod_Mailed check
# customerID
# 0002-ORFBO                               0                           1
# 0003-MKNFE                               0                           1
# 0004-TLHLJ                               1                           0
# 0011-IGKFF                               1                           0
# 0013-EXCHZ                               0                           1
#
# [5 rows x 45 columns]

# %%
# Splitting into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Creating StandardScaler instance
scaler = StandardScaler()

# Fitting Standard Scaler
X_scaler = scaler.fit(X_train)

# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Fitting the Decision Tree Model

# %%
# Creating the decision tree classifier instance
model = tree.DecisionTreeClassifier()

# %%
# Fitting the model
model = model.fit(X_train_scaled, y_train)

# %%
tree_predictions = model.predict(X_test_scaled)

# %%
print(classification_report(y_test, tree_predictions))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.83      0.79      0.81      1305
#          Yes       0.48      0.55      0.51       456
#
#     accuracy                           0.73      1761
#    macro avg       0.66      0.67      0.66      1761
# weighted avg       0.74      0.73      0.73      1761

# %%
# Create DOT data
dot_data = tree.export_graphviz(
    model, out_file=None, feature_names=X.columns, class_names=["0", "1"], filled=True
)

# Draw graph
graph = pydotplus.graph_from_dot_data(dot_data)

# Show graph
Image(graph.create_png())

# %% [markdown]
# ## DF adjustments from HG

# %%
#narrow down the amount of columns (Do we want to keep this?)
new_df=customer_churn_df[["customerID","MonthlyCharges", "TotalCharges", "Churn"]]
new_df
# Out:
#       customerID  MonthlyCharges  TotalCharges  Churn
# 0     0002-ORFBO           65.60        593.30      0
# 1     0003-MKNFE           59.90        542.40      0
# 2     0004-TLHLJ           73.90        280.85      1
# 3     0011-IGKFF           98.00       1237.85      1
# 4     0013-EXCHZ           83.90        267.40      1
# ...          ...             ...           ...    ...
# 7038  9987-LUTYD           55.15        742.90      0
# 7039  9992-RRAMN           85.10       1873.70      1
# 7040  9992-UJOEL           50.30         92.75      0
# 7041  9993-LHIEB           67.85       4627.65      0
# 7042  9995-HOTOH           59.00       3707.60      0
#
# [7043 rows x 4 columns]

# %%
# use get dummies to transform categorical data to binary
new_df=pd.get_dummies(new_df,columns=["Churn"],dtype=float).copy()
new_df.head()
# Out:
#    customerID  MonthlyCharges  TotalCharges  Churn_0  Churn_1
# 0  0002-ORFBO            65.6        593.30      1.0      0.0
# 1  0003-MKNFE            59.9        542.40      1.0      0.0
# 2  0004-TLHLJ            73.9        280.85      0.0      1.0
# 3  0011-IGKFF            98.0       1237.85      0.0      1.0
# 4  0013-EXCHZ            83.9        267.40      0.0      1.0

# %%
dummies_df_1 = pd.get_dummies(customer_churn_df["Dependents"])
dummies_df_1.head()
# Out:
#    0  1
# 0  0  1
# 1  1  0
# 2  1  0
# 3  1  0
# 4  1  0

# %%
customer_churn_df_dummies = pd.get_dummies(customer_churn_df["PhoneService"])
customer_churn_df_dummies.head()
# Out:
#    0  1
# 0  0  1
# 1  0  1
# 2  0  1
# 3  0  1
# 4  0  1

# %%
customer_churn_df_dummies
# Out:
#       0  1
# 0     0  1
# 1     0  1
# 2     0  1
# 3     0  1
# 4     0  1
# ...  .. ..
# 7038  0  1
# 7039  0  1
# 7040  0  1
# 7041  0  1
# 7042  1  0
#
# [7043 rows x 2 columns]

# %%
#standardize data for numerical values
from sklearn.preprocessing import StandardScaler

# %%
X=new_df[["MonthlyCharges", "TotalCharges"]]
X.head()
# Out:
#    MonthlyCharges  TotalCharges
# 0            65.6        593.30
# 1            59.9        542.40
# 2            73.9        280.85
# 3            98.0       1237.85
# 4            83.9        267.40

# %%
y=new_df["Churn"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Churn'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-57878834d62c> in <module>
# ----> 1 y=new_df["Churn"]
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Churn'

# %%
x_scaled = StandardScaler().fit_transform(new_df[["MonthlyCharges", "TotalCharges"]])

# %%
#run model, fit to model and backtest

# %%
customer_churn_df.dtypes

# %%
X=customer_churn_df_scaled[["MonthlyCharges", "TotalCharges"]]
X.head()

# %%
customer_churn_prediction = pd.concat([new_df, ], axis=1)
